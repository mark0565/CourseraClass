# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mark Fedun**
#
#  Construction worker soon to be data scientist

# %% [markdown]
# *I am interested in becoming a data scientist because I want to understand the reasoning behind the decisions that businesses make. Another reason is because I think that data science is an important skill for me to learn for future job security.*

# %% [markdown]
# ### The code below will be an example of simple arithmetic featuring variables

# %%
y=2
x=3
x + y
# Out:
# 5

# %% [markdown]
# 1. Effort
# 2. Courage
# 3. Discipline
#
#
# ~~The world is flat~~
#
# ![dog picture.jpg](attachment:32e2a75c-7a4d-4cd2-9ea4-72ca8ece5414.jpg)
